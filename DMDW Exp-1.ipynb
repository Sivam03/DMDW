# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
warnings.filterwarnings("ignore")
from matplotlib import pyplot
data = pd.read_csv('Iris.csv')
data.hist()
pyplot.show()

# %%
data=pd.read_csv("Iris.csv")

# %%
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>]], dtype=object)

# %%
data.plot(kind='box', subplots=True, layout=(3,3), sharex=False,sharey=False)
# Out:
# 150              Axes(0.125,0.653529;0.227941x0.226471)
# 4             Axes(0.398529,0.653529;0.227941x0.226471)
# setosa        Axes(0.672059,0.653529;0.227941x0.226471)
# versicolor       Axes(0.125,0.381765;0.227941x0.226471)
# virginica     Axes(0.398529,0.381765;0.227941x0.226471)
# dtype: object

# %%
correlations = data.corr()
'''
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(correlations)
ax.set_yticklabels(correlations)
'''
sns.heatmap(correlations,annot=True)
# Out:
# <Axes: >
